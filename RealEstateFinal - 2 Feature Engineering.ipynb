# %% [markdown]
# W207: Final Project
# ===========
#
# Our team (Danish Iqbal, KC Tobin, Jason Vantomme) is working through the Kaggle "House Prices: Advanced Regression Techniques" competition @ https://www.kaggle.com/c/house-prices-advanced-regression-techniques.
#
# Our first step is to scrub the data and generate effective features from what is provided.  We have divided this process into three parts, one for each team member.

# %%
# ENVIRONMENT SETUP

# This tells matplotlib not to try opening a new window for each plot.
# %matplotlib inline

import datetime as dt
import pandas as pd
import numpy as np
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures as PF, StandardScaler
from sklearn.decomposition import PCA
from sklearn.linear_model import LinearRegression, Ridge
from sklearn.naive_bayes import MultinomialNB, GaussianNB
from sklearn.feature_selection import RFE
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn import linear_model as lm
from sklearn import preprocessing
from sklearn import metrics
from scipy.stats import norm
from scipy import stats

import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

pd.set_option('display.precision',6)
pd.set_option('display.max_columns',None) 
pd.set_option('display.max_rows',None) 
pd.set_option('display.max_colwidth',1000)

# %%
# make sure you have the latest version of pandas (>=0.19.0) otherwise the 'category' type will throw an error

colTypesDict = {"MSSubClass":'category',"MSZoning":'category',"Street":'category',"Alley":'category',
                "LotShape":'category',"LandContour":'category',"Utilities":'category',
                "LotConfig":'category',"LandSlope":'category',"Neighborhood":'category',"Condition1":'category',
                "Condition2":'category',"BldgType":'category',"HouseStyle":'category',"RoofStyle":'category',
                "RoofMatl":'category',"Exterior1st":'category',"Exterior2nd":'category',"MasVnrType":'category',
                "ExterQual":'category',"ExterCond":'category',"Foundation":'category',
                "BsmtQual":'category',"BsmtCond":'category',"BsmtExposure":'category',"BsmtFinType1":'category',
                "BsmtFinType2":'category',"Heating":'category',"HeatingQC":'category',"CentralAir":'category',
                "Electrical":'category',"KitchenQual":'category',"Functional":'category',"FireplaceQu":'category',
                "GarageType":'category',"GarageFinish":'category',
                "GarageQual":'category',"GarageCond":'category',"PavedDrive":'category',
                "PoolQC":'category',"Fence":'category',"MiscFeature":'category',
                "SaleType":'category',"SaleCondition":'category'}

# LOAD THE PROVIDED TRAINING DATA
train = pd.read_csv('data/train.csv',delimiter=',',header=0,dtype=colTypesDict,na_values=["NA"])
test = pd.read_csv('data/test.csv',delimiter=',',header=0)

# %%
print train.shape
print test.shape

print train.describe(include='all')
# Out:
# (1460, 81)
# (1459, 80)
#                  Id MSSubClass MSZoning  LotFrontage        LotArea Street  \
# count   1460.000000       1460     1460  1201.000000    1460.000000   1460
# unique          NaN         15        5          NaN            NaN      2
# top             NaN         20       RL          NaN            NaN   Pave
# freq            NaN        536     1151          NaN            NaN   1454
# mean     730.500000        NaN      NaN    70.049958   10516.828082    NaN
# std      421.610009        NaN      NaN    24.284752    9981.264932    NaN
# min        1.000000        NaN      NaN    21.000000    1300.000000    NaN
# 25%      365.750000        NaN      NaN    59.000000    7553.500000    NaN
# 50%      730.500000        NaN      NaN    69.000000    9478.500000    NaN
# 75%     1095.250000        NaN      NaN    80.000000   11601.500000    NaN
# max     1460.000000        NaN      NaN   313.000000  215245.000000    NaN
#
#        Alley LotShape LandContour Utilities LotConfig LandSlope Neighborhood  \
# count     91     1460        1460      1460      1460      1460         1460
# unique     2        4           4         2         5         3           25
# top     Grvl      Reg         Lvl    AllPub    Inside       Gtl        NAmes
# freq      50      925        1311      1459      1052      1382          225
# mean     NaN      NaN         NaN       NaN       NaN       NaN          NaN
# std      NaN      NaN         NaN       NaN       NaN       NaN          NaN
# min      NaN      NaN         NaN       NaN       NaN       NaN          NaN
# 25%      NaN      NaN         NaN       NaN       NaN       NaN          NaN
# 50%      NaN      NaN         NaN       NaN       NaN       NaN          NaN
# 75%      NaN      NaN         NaN       NaN       NaN       NaN          NaN
# max      NaN      NaN         NaN       NaN       NaN       NaN          NaN
#
#        Condition1 Condition2 BldgType HouseStyle  OverallQual  OverallCond  \
# count        1460       1460     1460       1460  1460.000000  1460.000000
# unique          9          8        5          8          NaN          NaN
# top          Norm       Norm     1Fam     1Story          NaN          NaN
# freq         1260       1445     1220        726          NaN          NaN
# mean          NaN        NaN      NaN        NaN     6.099315     5.575342
# std           NaN        NaN      NaN        NaN     1.382997     1.112799
# min           NaN        NaN      NaN        NaN     1.000000     1.000000
# 25%           NaN        NaN      NaN        NaN     5.000000     5.000000
# 50%           NaN        NaN      NaN        NaN     6.000000     5.000000
# 75%           NaN        NaN      NaN        NaN     7.000000     6.000000
# max           NaN        NaN      NaN        NaN    10.000000     9.000000
#
#           YearBuilt  YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd  \
# count   1460.000000   1460.000000      1460     1460        1460        1460
# unique          NaN           NaN         6        8          15          16
# top             NaN           NaN     Gable  CompShg     VinylSd     VinylSd
# freq            NaN           NaN      1141     1434         515         504
# mean    1971.267808   1984.865753       NaN      NaN         NaN         NaN
# std       30.202904     20.645407       NaN      NaN         NaN         NaN
# min     1872.000000   1950.000000       NaN      NaN         NaN         NaN
# 25%     1954.000000   1967.000000       NaN      NaN         NaN         NaN
# 50%     1973.000000   1994.000000       NaN      NaN         NaN         NaN
# 75%     2000.000000   2004.000000       NaN      NaN         NaN         NaN
# max     2010.000000   2010.000000       NaN      NaN         NaN         NaN
#
#        MasVnrType   MasVnrArea ExterQual ExterCond Foundation BsmtQual  \
# count        1452  1452.000000      1460      1460       1460     1423
# unique          4          NaN         4         5          6        4
# top          None          NaN        TA        TA      PConc       TA
# freq          864          NaN       906      1282        647      649
# mean          NaN   103.685262       NaN       NaN        NaN      NaN
# std           NaN   181.066207       NaN       NaN        NaN      NaN
# min           NaN     0.000000       NaN       NaN        NaN      NaN
# 25%           NaN     0.000000       NaN       NaN        NaN      NaN
# 50%           NaN     0.000000       NaN       NaN        NaN      NaN
# 75%           NaN   166.000000       NaN       NaN        NaN      NaN
# max           NaN  1600.000000       NaN       NaN        NaN      NaN
#
#        BsmtCond BsmtExposure BsmtFinType1   BsmtFinSF1 BsmtFinType2  \
# count      1423         1422         1423  1460.000000         1422
# unique        4            4            6          NaN            6
# top          TA           No          Unf          NaN          Unf
# freq       1311          953          430          NaN         1256
# mean        NaN          NaN          NaN   443.639726          NaN
# std         NaN          NaN          NaN   456.098091          NaN
# min         NaN          NaN          NaN     0.000000          NaN
# 25%         NaN          NaN          NaN     0.000000          NaN
# 50%         NaN          NaN          NaN   383.500000          NaN
# 75%         NaN          NaN          NaN   712.250000          NaN
# max         NaN          NaN          NaN  5644.000000          NaN
#
#          BsmtFinSF2    BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir  \
# count   1460.000000  1460.000000  1460.000000    1460      1460       1460
# unique          NaN          NaN          NaN       6         5          2
# top             NaN          NaN          NaN    GasA        Ex          Y
# freq            NaN          NaN          NaN    1428       741       1365
# mean      46.549315   567.240411  1057.429452     NaN       NaN        NaN
# std      161.319273   441.866955   438.705324     NaN       NaN        NaN
# min        0.000000     0.000000     0.000000     NaN       NaN        NaN
# 25%        0.000000   223.000000   795.750000     NaN       NaN        NaN
# 50%        0.000000   477.500000   991.500000     NaN       NaN        NaN
# 75%        0.000000   808.000000  1298.250000     NaN       NaN        NaN
# max     1474.000000  2336.000000  6110.000000     NaN       NaN        NaN
#
#        Electrical     1stFlrSF     2ndFlrSF  LowQualFinSF    GrLivArea  \
# count        1459  1460.000000  1460.000000   1460.000000  1460.000000
# unique          5          NaN          NaN           NaN          NaN
# top         SBrkr          NaN          NaN           NaN          NaN
# freq         1334          NaN          NaN           NaN          NaN
# mean          NaN  1162.626712   346.992466      5.844521  1515.463699
# std           NaN   386.587738   436.528436     48.623081   525.480383
# min           NaN   334.000000     0.000000      0.000000   334.000000
# 25%           NaN   882.000000     0.000000      0.000000  1129.500000
# 50%           NaN  1087.000000     0.000000      0.000000  1464.000000
# 75%           NaN  1391.250000   728.000000      0.000000  1776.750000
# max           NaN  4692.000000  2065.000000    572.000000  5642.000000
#
#         BsmtFullBath  BsmtHalfBath     FullBath     HalfBath  BedroomAbvGr  \
# count    1460.000000   1460.000000  1460.000000  1460.000000   1460.000000
# unique           NaN           NaN          NaN          NaN           NaN
# top              NaN           NaN          NaN          NaN           NaN
# freq             NaN           NaN          NaN          NaN           NaN
# mean        0.425342      0.057534     1.565068     0.382877      2.866438
# std         0.518911      0.238753     0.550916     0.502885      0.815778
# min         0.000000      0.000000     0.000000     0.000000      0.000000
# 25%         0.000000      0.000000     1.000000     0.000000      2.000000
# 50%         0.000000      0.000000     2.000000     0.000000      3.000000
# 75%         1.000000      0.000000     2.000000     1.000000      3.000000
# max         3.000000      2.000000     3.000000     2.000000      8.000000
#
#         KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional   Fireplaces  \
# count    1460.000000        1460   1460.000000       1460  1460.000000
# unique           NaN           4           NaN          7          NaN
# top              NaN          TA           NaN        Typ          NaN
# freq             NaN         735           NaN       1360          NaN
# mean        1.046575         NaN      6.517808        NaN     0.613014
# std         0.220338         NaN      1.625393        NaN     0.644666
# min         0.000000         NaN      2.000000        NaN     0.000000
# 25%         1.000000         NaN      5.000000        NaN     0.000000
# 50%         1.000000         NaN      6.000000        NaN     1.000000
# 75%         1.000000         NaN      7.000000        NaN     1.000000
# max         3.000000         NaN     14.000000        NaN     3.000000
#
#        FireplaceQu GarageType  GarageYrBlt GarageFinish   GarageCars  \
# count          770       1379  1379.000000         1379  1460.000000
# unique           5          6          NaN            3          NaN
# top             Gd     Attchd          NaN          Unf          NaN
# freq           380        870          NaN          605          NaN
# mean           NaN        NaN  1978.506164          NaN     1.767123
# std            NaN        NaN    24.689725          NaN     0.747315
# min            NaN        NaN  1900.000000          NaN     0.000000
# 25%            NaN        NaN  1961.000000          NaN     1.000000
# 50%            NaN        NaN  1980.000000          NaN     2.000000
# 75%            NaN        NaN  2002.000000          NaN     2.000000
# max            NaN        NaN  2010.000000          NaN     4.000000
#
#          GarageArea GarageQual GarageCond PavedDrive   WoodDeckSF  \
# count   1460.000000       1379       1379       1460  1460.000000
# unique          NaN          5          5          3          NaN
# top             NaN         TA         TA          Y          NaN
# freq            NaN       1311       1326       1340          NaN
# mean     472.980137        NaN        NaN        NaN    94.244521
# std      213.804841        NaN        NaN        NaN   125.338794
# min        0.000000        NaN        NaN        NaN     0.000000
# 25%      334.500000        NaN        NaN        NaN     0.000000
# 50%      480.000000        NaN        NaN        NaN     0.000000
# 75%      576.000000        NaN        NaN        NaN   168.000000
# max     1418.000000        NaN        NaN        NaN   857.000000
#
#         OpenPorchSF  EnclosedPorch    3SsnPorch  ScreenPorch     PoolArea  \
# count   1460.000000    1460.000000  1460.000000  1460.000000  1460.000000
# unique          NaN            NaN          NaN          NaN          NaN
# top             NaN            NaN          NaN          NaN          NaN
# freq            NaN            NaN          NaN          NaN          NaN
# mean      46.660274      21.954110     3.409589    15.060959     2.758904
# std       66.256028      61.119149    29.317331    55.757415    40.177307
# min        0.000000       0.000000     0.000000     0.000000     0.000000
# 25%        0.000000       0.000000     0.000000     0.000000     0.000000
# 50%       25.000000       0.000000     0.000000     0.000000     0.000000
# 75%       68.000000       0.000000     0.000000     0.000000     0.000000
# max      547.000000     552.000000   508.000000   480.000000   738.000000
#
#        PoolQC  Fence MiscFeature       MiscVal       MoSold       YrSold  \
# count       7    281          54   1460.000000  1460.000000  1460.000000
# unique      3      4           4           NaN          NaN          NaN
# top        Gd  MnPrv        Shed           NaN          NaN          NaN
# freq        3    157          49           NaN          NaN          NaN
# mean      NaN    NaN         NaN     43.489041     6.321918  2007.815753
# std       NaN    NaN         NaN    496.123024     2.703626     1.328095
# min       NaN    NaN         NaN      0.000000     1.000000  2006.000000
# 25%       NaN    NaN         NaN      0.000000     5.000000  2007.000000
# 50%       NaN    NaN         NaN      0.000000     6.000000  2008.000000
# 75%       NaN    NaN         NaN      0.000000     8.000000  2009.000000
# max       NaN    NaN         NaN  15500.000000    12.000000  2010.000000
#
#        SaleType SaleCondition      SalePrice
# count      1460          1460    1460.000000
# unique        9             6            NaN
# top          WD        Normal            NaN
# freq       1267          1198            NaN
# mean        NaN           NaN  180921.195890
# std         NaN           NaN   79442.502883
# min         NaN           NaN   34900.000000
# 25%         NaN           NaN  129975.000000
# 50%         NaN           NaN  163000.000000
# 75%         NaN           NaN  214000.000000
# max         NaN           NaN  755000.000000

# %%
## SET 1 (Danish)

##

train['MasVnrArea'].fillna(0, inplace=True)
train['MasVnrArea2'] = train['MasVnrArea'].astype(int) 

train['MasVnrArea2_0'] = train['MasVnrArea2']==0
train['MasVnrArea2_50'] = (train['MasVnrArea2']>0) & (train['MasVnrArea2']<50)
train['MasVnrArea2_100'] = (train['MasVnrArea2']>50) & (train['MasVnrArea2']<100)
train['MasVnrArea2_150'] = (train['MasVnrArea2']>100) & (train['MasVnrArea2']<150)
train['MasVnrArea2_200'] = (train['MasVnrArea2']>150) & (train['MasVnrArea2']<200)
train['MasVnrArea2_250'] = (train['MasVnrArea2']>200) & (train['MasVnrArea2']<250)
train['MasVnrArea2_300'] = (train['MasVnrArea2']>250) & (train['MasVnrArea2']<300)
train['MasVnrArea2_350'] = (train['MasVnrArea2']>300) & (train['MasVnrArea2']<350)
train['MasVnrArea2_400'] = (train['MasVnrArea2']>350) & (train['MasVnrArea2']<400)
train['MasVnrArea2_other'] = (train['MasVnrArea2']>400)

#--

train['MSSubClass_60'] = train['MSSubClass']==60
train['MSSubClass_50'] = train['MSSubClass']==50
train['MSSubClass_120'] = train['MSSubClass']==120
train['MSSubClass_80'] = train['MSSubClass']==80
train['MSSubClass_160'] = train['MSSubClass']==160
train['MSSubClass_90'] = train['MSSubClass']==90
train['MSSubClass_30'] = train['MSSubClass']==30
train['MSSubClass_70'] = train['MSSubClass']==70
train['MSSubClass_other'] = (train['MSSubClass']==85) | (train['MSSubClass']==190) | (train['MSSubClass']==75)  | (train['MSSubClass']==180) | (train['MSSubClass']==45) | (train['MSSubClass']==40)

train['LotFrontage_none'] = train['LotFrontage']==0
train['LotFrontage_50'] = (train['LotFrontage']>0) & (train['LotFrontage']<50)
train['LotFrontage_60'] = (train['LotFrontage']>50) & (train['LotFrontage']<60)
train['LotFrontage_70'] = (train['LotFrontage']>60) & (train['LotFrontage']<70)
train['LotFrontage_80'] = (train['LotFrontage']>70) & (train['LotFrontage']<80)
train['LotFrontage_90'] = (train['LotFrontage']>80) & (train['LotFrontage']<90)
train['LotFrontage_other'] = train['LotFrontage']>90

train['LotArea_5'] = train['LotArea']<5000
train['LotArea_6'] = (train['LotArea']>5000) & (train['LotArea']<6000)
train['LotArea_7'] = (train['LotArea']>6000) & (train['LotArea']<7000)
train['LotArea_8'] = (train['LotArea']>7000) & (train['LotArea']<8000)
train['LotArea_9'] = (train['LotArea']>8000) & (train['LotArea']<9000)
train['LotArea_10'] = (train['LotArea']>9000) & (train['LotArea']<10000)
train['LotArea_11'] = (train['LotArea']>10000) & (train['LotArea']<11000)
train['LotArea_12'] = (train['LotArea']>11000) & (train['LotArea']<12000)
train['LotArea_13'] = (train['LotArea']>12000) & (train['LotArea']<13000)
train['LotArea_14'] = (train['LotArea']>13000) & (train['LotArea']<14000)
train['LotArea_other'] = (train['LotArea']>14000) 

train['YearBuilt_30'] = train['YearBuilt']<1930
train['YearBuilt_40'] = (train['YearBuilt']>1930) & (train['YearBuilt']<1940)
train['YearBuilt_50'] = (train['YearBuilt']>1940) & (train['YearBuilt']<1950)
train['YearBuilt_60'] = (train['YearBuilt']>1950) & (train['YearBuilt']<1960)
train['YearBuilt_70'] = (train['YearBuilt']>1960) & (train['YearBuilt']<1970)
train['YearBuilt_80'] = (train['YearBuilt']>1970) & (train['YearBuilt']<1980)
train['YearBuilt_90'] = (train['YearBuilt']>1980) & (train['YearBuilt']<1990)
train['YearBuilt_00'] = (train['YearBuilt']>1990) & (train['YearBuilt']<2005)

train['YearRemodAdd_50'] = (train['YearRemodAdd']>1950) & (train['YearRemodAdd']<1960)
train['YearRemodAdd_60'] = (train['YearRemodAdd']>1960) & (train['YearRemodAdd']<1970)
train['YearRemodAdd_70'] = (train['YearRemodAdd']>1970) & (train['YearRemodAdd']<1980)
train['YearRemodAdd_80'] = (train['YearRemodAdd']>1980) & (train['YearRemodAdd']<1990)
train['YearRemodAdd_90'] = (train['YearRemodAdd']>1990) & (train['YearRemodAdd']<2000)
train['YearRemodAdd_00'] = (train['YearRemodAdd']>2000)

#--
print train.shape
for col in train.columns:
    print col
# Out:
# (1460, 133)
# Id
# MSSubClass
# MSZoning
# LotFrontage
# LotArea
# Street
# Alley
# LotShape
# LandContour
# Utilities
# LotConfig
# LandSlope
# Neighborhood
# Condition1
# Condition2
# BldgType
# HouseStyle
# OverallQual
# OverallCond
# YearBuilt
# YearRemodAdd
# RoofStyle
# RoofMatl
# Exterior1st
# Exterior2nd
# MasVnrType
# MasVnrArea
# ExterQual
# ExterCond
# Foundation
# BsmtQual
# BsmtCond
# BsmtExposure
# BsmtFinType1
# BsmtFinSF1
# BsmtFinType2
# BsmtFinSF2
# BsmtUnfSF
# TotalBsmtSF
# Heating
# HeatingQC
# CentralAir
# Electrical
# 1stFlrSF
# 2ndFlrSF
# LowQualFinSF
# GrLivArea
# BsmtFullBath
# BsmtHalfBath
# FullBath
# HalfBath
# BedroomAbvGr
# KitchenAbvGr
# KitchenQual
# TotRmsAbvGrd
# Functional
# Fireplaces
# FireplaceQu
# GarageType
# GarageYrBlt
# GarageFinish
# GarageCars
# GarageArea
# GarageQual
# GarageCond
# PavedDrive
# WoodDeckSF
# OpenPorchSF
# EnclosedPorch
# 3SsnPorch
# ScreenPorch
# PoolArea
# PoolQC
# Fence
# MiscFeature
# MiscVal
# MoSold
# YrSold
# SaleType
# SaleCondition
# SalePrice
# MasVnrArea2
# MasVnrArea2_0
# MasVnrArea2_50
# MasVnrArea2_100
# MasVnrArea2_150
# MasVnrArea2_200
# MasVnrArea2_250
# MasVnrArea2_300
# MasVnrArea2_350
# MasVnrArea2_400
# MasVnrArea2_other
# MSSubClass_60
# MSSubClass_50
# MSSubClass_120
# MSSubClass_80
# MSSubClass_160
# MSSubClass_90
# MSSubClass_30
# MSSubClass_70
# MSSubClass_other
# LotFrontage_none
# LotFrontage_50
# LotFrontage_60
# LotFrontage_70
# LotFrontage_80
# LotFrontage_90
# LotFrontage_other
# LotArea_5
# LotArea_6
# LotArea_7
# LotArea_8
# LotArea_9
# LotArea_10
# LotArea_11
# LotArea_12
# LotArea_13
# LotArea_14
# LotArea_other
# YearBuilt_30
# YearBuilt_40
# YearBuilt_50
# YearBuilt_60
# YearBuilt_70
# YearBuilt_80
# YearBuilt_90
# YearBuilt_00
# YearRemodAdd_50
# YearRemodAdd_60
# YearRemodAdd_70
# YearRemodAdd_80
# YearRemodAdd_90
# YearRemodAdd_00

# %%
## SET 2 (KC)

#handle NAs with train; categoricals
train["BsmtFinType2"] = train["BsmtFinType2"].fillna(method="ffill")
train["BsmtExposure"] = train["BsmtExposure"].fillna(method="ffill")

#handle NAs with test; ints
test["BsmtFinSF1"] = train["BsmtFinSF1"].fillna(0)
test["BsmtFinSF2"] = train["BsmtFinSF2"].fillna(0)
test["TotalBsmtSF"] = train["TotalBsmtSF"].fillna(0)
test["BsmtUnfSF"] = train["BsmtUnfSF"].fillna(0)
test["BsmtHalfBath"] = train["BsmtHalfBath"].fillna(0)
test["BsmtFullBath"] = train["BsmtFullBath"].fillna(0)

#handle NAs with test; categoricals
test["KitchenQual"] = test["KitchenQual"].fillna(method="ffill")
test["BsmtCond"] = test["BsmtCond"].fillna(method="ffill")
test["BsmtQual"] = test["BsmtQual"].fillna(method="ffill")
test["BsmtExposure"] = test["BsmtExposure"].fillna(method="ffill")

#create other rooms columns
train["OtherRmsAbvGr"] = train["TotRmsAbvGrd"] - (train["BedroomAbvGr"]+train["KitchenAbvGr"])
test["OtherRmsAbvGr"] = test["TotRmsAbvGrd"] - (test["BedroomAbvGr"]+test["KitchenAbvGr"])

#create binary columns
train["HasBsmt"] = train["TotalBsmtSF"] > 0
train["Has2ndFlr"] = train["2ndFlrSF"] > 0
test["HasBsmt"] = test["TotalBsmtSF"] > 0
test["Has2ndFlr"] = test["2ndFlrSF"] > 0

#drop total columns
train = train.drop(["GrLivArea", "TotalBsmtSF", "TotRmsAbvGrd"], axis = 1)
test = test.drop(["GrLivArea", "TotalBsmtSF", "TotRmsAbvGrd"], axis = 1)

#log transforms of area
train["BsmtFinSF1"] = np.log(train["BsmtFinSF1"]+1)
train["BsmtFinSF2"] = np.log(train["BsmtFinSF2"]+1)
train["BsmtUnfSF"] = np.log(train["BsmtUnfSF"]+1)
train["1stFlrSF"] = np.log(train["1stFlrSF"]+1)
train["2ndFlrSF"] = np.log(train["2ndFlrSF"]+1)
train["LowQualFinSF"] = np.log(train["LowQualFinSF"]+1)

test["BsmtFinSF1"] = np.log(test["BsmtFinSF1"]+1)
test["BsmtFinSF2"] = np.log(test["BsmtFinSF2"]+1)
test["BsmtUnfSF"] = np.log(test["BsmtUnfSF"]+1)
test["1stFlrSF"] = np.log(test["1stFlrSF"]+1)
test["2ndFlrSF"] = np.log(test["2ndFlrSF"]+1)
test["LowQualFinSF"] = np.log(test["LowQualFinSF"]+1)

print train.shape
for col in train.columns:
    print col
# Out:
# (1460, 133)
# Id
# MSSubClass
# MSZoning
# LotFrontage
# LotArea
# Street
# Alley
# LotShape
# LandContour
# Utilities
# LotConfig
# LandSlope
# Neighborhood
# Condition1
# Condition2
# BldgType
# HouseStyle
# OverallQual
# OverallCond
# YearBuilt
# YearRemodAdd
# RoofStyle
# RoofMatl
# Exterior1st
# Exterior2nd
# MasVnrType
# MasVnrArea
# ExterQual
# ExterCond
# Foundation
# BsmtQual
# BsmtCond
# BsmtExposure
# BsmtFinType1
# BsmtFinSF1
# BsmtFinType2
# BsmtFinSF2
# BsmtUnfSF
# Heating
# HeatingQC
# CentralAir
# Electrical
# 1stFlrSF
# 2ndFlrSF
# LowQualFinSF
# BsmtFullBath
# BsmtHalfBath
# FullBath
# HalfBath
# BedroomAbvGr
# KitchenAbvGr
# KitchenQual
# Functional
# Fireplaces
# FireplaceQu
# GarageType
# GarageYrBlt
# GarageFinish
# GarageCars
# GarageArea
# GarageQual
# GarageCond
# PavedDrive
# WoodDeckSF
# OpenPorchSF
# EnclosedPorch
# 3SsnPorch
# ScreenPorch
# PoolArea
# PoolQC
# Fence
# MiscFeature
# MiscVal
# MoSold
# YrSold
# SaleType
# SaleCondition
# SalePrice
# MasVnrArea2
# MasVnrArea2_0
# MasVnrArea2_50
# MasVnrArea2_100
# MasVnrArea2_150
# MasVnrArea2_200
# MasVnrArea2_250
# MasVnrArea2_300
# MasVnrArea2_350
# MasVnrArea2_400
# MasVnrArea2_other
# MSSubClass_60
# MSSubClass_50
# MSSubClass_120
# MSSubClass_80
# MSSubClass_160
# MSSubClass_90
# MSSubClass_30
# MSSubClass_70
# MSSubClass_other
# LotFrontage_none
# LotFrontage_50
# LotFrontage_60
# LotFrontage_70
# LotFrontage_80
# LotFrontage_90
# LotFrontage_other
# LotArea_5
# LotArea_6
# LotArea_7
# LotArea_8
# LotArea_9
# LotArea_10
# LotArea_11
# LotArea_12
# LotArea_13
# LotArea_14
# LotArea_other
# YearBuilt_30
# YearBuilt_40
# YearBuilt_50
# YearBuilt_60
# YearBuilt_70
# YearBuilt_80
# YearBuilt_90
# YearBuilt_00
# YearRemodAdd_50
# YearRemodAdd_60
# YearRemodAdd_70
# YearRemodAdd_80
# YearRemodAdd_90
# YearRemodAdd_00
# OtherRmsAbvGr
# HasBsmt
# Has2ndFlr

# %%
## SET 3 (Jason)

##
##  PORCH/DECK COLLAPSE/REMOVALS INTO ONE SQ FT MEASUREMENT (SUM OF ALL)
##
porches = train.loc[:,["WoodDeckSF","OpenPorchSF","EnclosedPorch","3SsnPorch","ScreenPorch"]]
reduced_porches = porches.sum(axis=1)
train["TotalPorchSqFt"] = reduced_porches
#
porches = test.loc[:,["WoodDeckSF","OpenPorchSF","EnclosedPorch","3SsnPorch","ScreenPorch"]]
reduced_porches = porches.sum(axis=1)
test["TotalPorchSqFt"] = reduced_porches

## ----------------------------
##  POOL MODIFICATIONS
## ----------------------------
train["HasPool"] = train["PoolArea"] > 0
train = train.drop( ["PoolArea"], axis=1 )
#
test["HasPool"] = test["PoolArea"] > 0
test = test.drop( ["PoolArea"], axis=1 )

## ----------------------------
##  FIREPLACE COLLAPSE/REMOVALS
## ----------------------------
manyFireplaces = 2
train["HasManyFireplaces"] = train["Fireplaces"] > manyFireplaces
test["HasManyFireplaces"] = test["Fireplaces"] > manyFireplaces

## ----------------------------
##  GARAGE COLLAPSE/REMOVALS
## ----------------------------
largeGarageSize = 800
train["HasLargeGarage"] = train["GarageArea"] > largeGarageSize
train = train.drop( ["GarageArea"], axis=1 )
#
test["HasLargeGarage"] = test["GarageArea"] > largeGarageSize
test = test.drop( ["GarageArea"], axis=1 )

print train["GarageYrBlt"].dtypes

print train.shape
for col in train.columns:
    print col
# Out:
# float64
# (1460, 135)
# Id
# MSSubClass
# MSZoning
# LotFrontage
# LotArea
# Street
# Alley
# LotShape
# LandContour
# Utilities
# LotConfig
# LandSlope
# Neighborhood
# Condition1
# Condition2
# BldgType
# HouseStyle
# OverallQual
# OverallCond
# YearBuilt
# YearRemodAdd
# RoofStyle
# RoofMatl
# Exterior1st
# Exterior2nd
# MasVnrType
# MasVnrArea
# ExterQual
# ExterCond
# Foundation
# BsmtQual
# BsmtCond
# BsmtExposure
# BsmtFinType1
# BsmtFinSF1
# BsmtFinType2
# BsmtFinSF2
# BsmtUnfSF
# Heating
# HeatingQC
# CentralAir
# Electrical
# 1stFlrSF
# 2ndFlrSF
# LowQualFinSF
# BsmtFullBath
# BsmtHalfBath
# FullBath
# HalfBath
# BedroomAbvGr
# KitchenAbvGr
# KitchenQual
# Functional
# Fireplaces
# FireplaceQu
# GarageType
# GarageYrBlt
# GarageFinish
# GarageCars
# GarageQual
# GarageCond
# PavedDrive
# WoodDeckSF
# OpenPorchSF
# EnclosedPorch
# 3SsnPorch
# ScreenPorch
# PoolQC
# Fence
# MiscFeature
# MiscVal
# MoSold
# YrSold
# SaleType
# SaleCondition
# SalePrice
# MasVnrArea2
# MasVnrArea2_0
# MasVnrArea2_50
# MasVnrArea2_100
# MasVnrArea2_150
# MasVnrArea2_200
# MasVnrArea2_250
# MasVnrArea2_300
# MasVnrArea2_350
# MasVnrArea2_400
# MasVnrArea2_other
# MSSubClass_60
# MSSubClass_50
# MSSubClass_120
# MSSubClass_80
# MSSubClass_160
# MSSubClass_90
# MSSubClass_30
# MSSubClass_70
# MSSubClass_other
# LotFrontage_none
# LotFrontage_50
# LotFrontage_60
# LotFrontage_70
# LotFrontage_80
# LotFrontage_90
# LotFrontage_other
# LotArea_5
# LotArea_6
# LotArea_7
# LotArea_8
# LotArea_9
# LotArea_10
# LotArea_11
# LotArea_12
# LotArea_13
# LotArea_14
# LotArea_other
# YearBuilt_30
# YearBuilt_40
# YearBuilt_50
# YearBuilt_60
# YearBuilt_70
# YearBuilt_80
# YearBuilt_90
# YearBuilt_00
# YearRemodAdd_50
# YearRemodAdd_60
# YearRemodAdd_70
# YearRemodAdd_80
# YearRemodAdd_90
# YearRemodAdd_00
# OtherRmsAbvGr
# HasBsmt
# Has2ndFlr
# TotalPorchSqFt
# HasPool
# HasManyFireplaces
# HasLargeGarage

# %%
#
# DO COMMON ACTIONS
#
## flatten categoricals and drop original features
encodeCols = train.select_dtypes(include=['category'])
print encodeCols
#for col in colsToEncode:
#    train = pd.concat([train,pd.get_dummies(train[col])])
    
#train = pd.get_dummies(train)
#test = pd.get_dummies(test)

## store the SalePrice as log of original
#train["SalePrice"] = train["SalePrice"].apply(np.log)

print train.shape
for col in train.columns:
    print col
# Out:
#      MSSubClass MSZoning Street Alley LotShape LandContour Utilities  \
# 0            60       RL   Pave   NaN      Reg         Lvl    AllPub
# 1            20       RL   Pave   NaN      Reg         Lvl    AllPub
# 2            60       RL   Pave   NaN      IR1         Lvl    AllPub
# 3            70       RL   Pave   NaN      IR1         Lvl    AllPub
# 4            60       RL   Pave   NaN      IR1         Lvl    AllPub
# 5            50       RL   Pave   NaN      IR1         Lvl    AllPub
# 6            20       RL   Pave   NaN      Reg         Lvl    AllPub
# 7            60       RL   Pave   NaN      IR1         Lvl    AllPub
# 8            50       RM   Pave   NaN      Reg         Lvl    AllPub
# 9           190       RL   Pave   NaN      Reg         Lvl    AllPub
# 10           20       RL   Pave   NaN      Reg         Lvl    AllPub
# 11           60       RL   Pave   NaN      IR1         Lvl    AllPub
# 12           20       RL   Pave   NaN      IR2         Lvl    AllPub
# 13           20       RL   Pave   NaN      IR1         Lvl    AllPub
# 14           20       RL   Pave   NaN      IR1         Lvl    AllPub
# 15           45       RM   Pave   NaN      Reg         Lvl    AllPub
# 16           20       RL   Pave   NaN      IR1         Lvl    AllPub
# 17           90       RL   Pave   NaN      Reg         Lvl    AllPub
# 18           20       RL   Pave   NaN      Reg         Lvl    AllPub
# 19           20       RL   Pave   NaN      Reg         Lvl    AllPub
# 20           60       RL   Pave   NaN      IR1         Lvl    AllPub
# 21           45       RM   Pave  Grvl      Reg         Bnk    AllPub
# 22           20       RL   Pave   NaN      Reg         Lvl    AllPub
# 23          120       RM   Pave   NaN      Reg         Lvl    AllPub
# 24           20       RL   Pave   NaN      IR1         Lvl    AllPub
# 25           20       RL   Pave   NaN      Reg         Lvl    AllPub
# 26           20       RL   Pave   NaN      Reg         Lvl    AllPub
# 27           20       RL   Pave   NaN      Reg         Lvl    AllPub
# 28           20       RL   Pave   NaN      IR1         Lvl    AllPub
# 29           30       RM   Pave   NaN      IR1         Lvl    AllPub
# 30           70  C (all)   Pave  Pave      Reg         Lvl    AllPub
# 31           20       RL   Pave   NaN      IR1         Lvl    AllPub
# 32           20       RL   Pave   NaN      Reg         Lvl    AllPub
# 33           20       RL   Pave   NaN      IR1         Lvl    AllPub
# 34          120       RL   Pave   NaN      Reg         Lvl    AllPub
# 35           60       RL   Pave   NaN      Reg         Lvl    AllPub
# 36           20       RL   Pave   NaN      Reg         Lvl    AllPub
# 37           20       RL   Pave   NaN      Reg         Lvl    AllPub
# 38           20       RL   Pave   NaN      Reg         Lvl    AllPub
# 39           90       RL   Pave   NaN      Reg         Lvl    AllPub
# 40           20       RL   Pave   NaN      Reg         Lvl    AllPub
# 41           20       RL   Pave   NaN      Reg         Lvl    AllPub
# 42           85       RL   Pave   NaN      IR1         Lvl    AllPub
# 43           20       RL   Pave   NaN      IR1         Lvl    AllPub
# 44           20       RL   Pave   NaN      Reg         Lvl    AllPub
# 45          120       RL   Pave   NaN      Reg         Lvl    AllPub
# 46           50       RL   Pave   NaN      IR1         Lvl    AllPub
# 47           20       FV   Pave   NaN      Reg         Lvl    AllPub
# 48          190       RM   Pave   NaN      Reg         Lvl    AllPub
# 49           20       RL   Pave   NaN      Reg         Lvl    AllPub
# 50           60       RL   Pave   NaN      IR2         Lvl    AllPub
# 51           50       RM   Pave   NaN      Reg         Lvl    AllPub
# 52           90       RM   Grvl   NaN      IR2         Bnk    AllPub
# 53           20       RL   Pave   NaN      IR1         Low    AllPub
# 54           80       RL   Pave   NaN      Reg         Bnk    AllPub
# 55           20       RL   Pave   NaN      IR1         Lvl    AllPub
# 56          160       FV   Pave  Pave      Reg         Lvl    AllPub
# 57           60       RL   Pave   NaN      IR1         Lvl    AllPub
# 58           60       RL   Pave   NaN      IR2         HLS    AllPub
# 59           20       RL   Pave   NaN      Reg         Bnk    AllPub
# 60           20       RL   Pave   NaN      Reg         Lvl    AllPub
# 61           75       RM   Pave   NaN      Reg         Lvl    AllPub
# 62          120       RL   Pave   NaN      IR1         Lvl    AllPub
# 63           70       RM   Pave   NaN      IR1         Bnk    AllPub
# 64           60       RL   Pave   NaN      Reg         Lvl    AllPub
# 65           60       RL   Pave   NaN      Reg         Lvl    AllPub
# 66           20       RL   Pave   NaN      Reg         Lvl    AllPub
# 67           20       RL   Pave   NaN      IR1         Lvl    AllPub
# 68           30       RM   Pave   NaN      Reg         Lvl    AllPub
# 69           50       RL   Pave   NaN      Reg         Lvl    AllPub
# 70           20       RL   Pave   NaN      IR1         Lvl    AllPub
# 71           20       RL   Pave   NaN      Reg         Lvl    AllPub
# 72           60       RL   Pave   NaN      IR1         Lvl    AllPub
# 73           20       RL   Pave   NaN      Reg         Lvl    AllPub
# 74           50       RM   Pave   NaN      Reg         Lvl    AllPub
# 75          180       RM   Pave   NaN      Reg         Lvl    AllPub
# 76           20       RL   Pave   NaN      IR1         Lvl    AllPub
# 77           50       RM   Pave   NaN      Reg         Lvl    AllPub
# 78           90       RL   Pave   NaN      Reg         Lvl    AllPub
# 79           50       RM   Pave  Grvl      Reg         Lvl    AllPub
# 80           60       RL   Pave   NaN      Reg         Lvl    AllPub
# 81          120       RM   Pave   NaN      Reg         Lvl    AllPub
# 82           20       RL   Pave   NaN      Reg         Lvl    AllPub
# 83           20       RL   Pave   NaN      IR1         Lvl    AllPub
# 84           80       RL   Pave   NaN      IR1         Lvl    AllPub
# 85           60       RL   Pave   NaN      Reg         Lvl    AllPub
# 86           60       RL   Pave   NaN      IR2         Lvl    AllPub
# 87          160       FV   Pave  Pave      Reg         Lvl    AllPub
# 88           50  C (all)   Pave   NaN      IR1         Lvl    AllPub
# 89           20       RL   Pave   NaN      Reg         Lvl    AllPub
# 90           20       RL   Pave   NaN      Reg         Lvl    AllPub
# 91           20       RL   Pave   NaN      Reg         Lvl    AllPub
# 92           30       RL   Pave  Grvl      IR1         HLS    AllPub
# 93          190  C (all)   Pave   NaN      Reg         Lvl    AllPub
# 94           60       RL   Pave   NaN      IR1         Lvl    AllPub
# 95           60       RL   Pave   NaN      IR2         Lvl    AllPub
# 96           20       RL   Pave   NaN      IR1         Lvl    AllPub
# 97           20       RL   Pave   NaN      Reg         HLS    AllPub
# 98           30       RL   Pave   NaN      Reg         Lvl    AllPub
# 99           20       RL   Pave   NaN      IR1         Lvl    AllPub
# 100          20       RL   Pave   NaN      IR1         Lvl    AllPub
# 101          60       RL   Pave   NaN      Reg         Lvl    AllPub
# 102          90       RL   Pave   NaN      Reg         Bnk    AllPub
# 103          20       RL   Pave   NaN      IR1         Lvl    AllPub
# 104          50       RM   Pave   NaN      Reg         Lvl    AllPub
# 105          60       FV   Pave   NaN      Reg         Lvl    AllPub
# 106          30       RM   Pave  Grvl      Reg         Lvl    AllPub
# 107          20       RM   Pave   NaN      Reg         Lvl    AllPub
# 108          50       RM   Pave   NaN      Reg         Lvl    AllPub
# 109          20       RL   Pave   NaN      IR1         Lvl    AllPub
# 110          50       RL   Pave   NaN      Reg         Lvl    AllPub
# 111          80       RL   Pave   NaN      IR1         Lvl    AllPub
# 112          60       RL   Pave   NaN      Reg         Lvl    AllPub
# 113          20       RL   Pave   NaN      Reg         Bnk    AllPub
# 114          70       RL   Pave   NaN      IR1         Lvl    AllPub
# 115         160       FV   Pave  Pave      Reg         Lvl    AllPub
# 116          20       RL   Pave   NaN      Reg         Lvl    AllPub
# 117          20       RL   Pave   NaN      Reg         Lvl    AllPub
# 118          60       RL   Pave   NaN      Reg         Lvl    AllPub
# 119          60       RL   Pave   NaN      Reg         Lvl    AllPub
# 120          80       RL   Pave   NaN      IR1         Low    AllPub
# 121          50       RM   Pave   NaN      Reg         Lvl    AllPub
# 122          20       RL   Pave   NaN      Reg         Lvl    AllPub
# 123         120       RL   Pave   NaN      Reg         Lvl    AllPub
# 124          20       RL   Pave   NaN      IR1         Lvl    AllPub
# 125         190       RM   Pave   NaN      Reg         Lvl    AllPub
# 126         120       RL   Pave   NaN      IR1         Lvl    AllPub
# 127          45       RM   Pave   NaN      IR1         Bnk    AllPub
# 128          60       RL   Pave   NaN      Reg         Lvl    AllPub
# 129          20       RL   Pave   NaN      Reg         Lvl    AllPub
# 130          60       RL   Pave   NaN      Reg         Lvl    AllPub
# 131          60       RL   Pave   NaN      IR1         Lvl    AllPub
# 132          20       RL   Pave   NaN      Reg         Lvl    AllPub
# 133          20       RL   Pave   NaN      IR1         Lvl    AllPub
# 134          20       RL   Pave   NaN      IR1         Lvl    AllPub
# 135          20       RL   Pave   NaN      Reg         Lvl    AllPub
# 136          20       RL   Pave   NaN      IR1         Lvl    AllPub
# 137          90       RL   Pave   NaN      Reg         Lvl    AllPub
# 138          60       RL   Pave   NaN      IR1         Lvl    AllPub
# 139          60       RL   Pave   NaN      IR1         Lvl    AllPub
# 140          20       RL   Pave   NaN      Reg         Lvl    AllPub
# 141          20       RL   Pave   NaN      Reg         Lvl    AllPub
# 142          50       RL   Pave   NaN      Reg         Lvl    AllPub
# 143          20       RL   Pave   NaN      IR1         Lvl    AllPub
# 144          90       RM   Pave   NaN      Reg         Lvl    AllPub
# 145         160       RM   Pave   NaN      Reg         Lvl    AllPub
# 146          30       RM   Pave   NaN      Reg         Lvl    AllPub
# 147          60       RL   Pave   NaN      IR1         Lvl    AllPub
# 148          20       RL   Pave   NaN      Reg         Lvl    AllPub
# 149          50       RM   Pave   NaN      Reg         Lvl    AllPub
# 150          20       RL   Pave   NaN      Reg         Lvl    AllPub
# 151          20       RL   Pave   NaN      Reg         Lvl    AllPub
# 152          60       RL   Pave   NaN      IR1         Lvl    AllPub
# 153          20       RL   Pave   NaN      Reg         Lvl    AllPub
# 154          30       RM   Pave   NaN      Reg         Lvl    AllPub
# 155          50       RL   Pave   NaN      Reg         Lvl    AllPub
# 156          20       RL   Pave   NaN      Reg         Lvl    AllPub
# 157          60       RL   Pave   NaN      Reg         Lvl    AllPub
# 158          60       FV   Pave   NaN      Reg         Lvl    AllPub
# 159          60       RL   Pave   NaN      IR1         HLS    AllPub
# 160          20       RL   Pave   NaN      IR1         Lvl    AllPub
# 161          60       RL   Pave   NaN      IR1         Lvl    AllPub
# 162          20       RL   Pave   NaN      Reg         Lvl    AllPub
# 163          45       RL   Pave   NaN      Reg         Lvl    AllPub
# 164          40       RM   Pave  Pave      Reg         Lvl    AllPub
# 165         190       RL   Pave   NaN      Reg         Lvl    AllPub
# 166          20       RL   Pave   NaN      IR1         Lvl    AllPub
# 167          60       RL   Pave   NaN      Reg         Lvl    AllPub
# 168          60       RL   Pave   NaN      IR1         Lvl    AllPub
# 169          20       RL   Pave   NaN      IR1         Lvl    AllPub
# 170          50       RM   Pave   NaN      IR1         Lvl    AllPub
# 171          20       RL   Pave   NaN      IR1         Lvl    AllPub
# 172         160       RL   Pave   NaN      IR1         Lvl    AllPub
# 173          20       RL   Pave   NaN      IR1         Lvl    AllPub
# 174          20       RL   Pave   NaN      IR1         Lvl    AllPub
# 175          20       RL   Pave   NaN      Reg         Lvl    AllPub
# 176          60       RL   Pave   NaN      IR1         Lvl    AllPub
# 177          50       RL   Pave   NaN      Reg         Lvl    AllPub
# 178          20       RL   Pave   NaN      IR1         Lvl    AllPub
# 179          30       RM   Pave   NaN      Reg         Lvl    AllPub
# 180         160       FV   Pave   NaN      Reg         Lvl    AllPub
# 181          70       RL   Pave   NaN      Reg         Lvl    AllPub
# 182          20       RL   Pave   NaN      Reg         Lvl    AllPub
# 183          50       RM   Pave   NaN      Reg         Lvl    AllPub
# 184          50       RL   Pave   NaN      IR1         Lvl    AllPub
# 185          75       RM   Pave   NaN      IR2         Lvl    AllPub
# 186          80       RL   Pave   NaN      IR1         Lvl    AllPub
# 187          50       RL   Pave   NaN      Reg         Lvl    AllPub
# 188          90       RL   Pave   NaN      Reg         Bnk    AllPub
# 189         120       RL   Pave   NaN      Reg         Lvl    AllPub
# 190          70       RL   Pave   NaN      Reg         Bnk    AllPub
# 191          60       RL   Pave   NaN      IR1         Lvl    AllPub
# 192          20       RL   Pave   NaN      IR1         Lvl    AllPub
# 193         160       RM   Pave   NaN      Reg         Lvl    AllPub
# 194          20       RL   Pave   NaN      IR1         Lvl    AllPub
# 195         160       RL   Pave   NaN      Reg         Lvl    AllPub
# 196          20       RL   Pave   NaN      Reg         Lvl    AllPub
# 197          75       RL   Pave   NaN      Reg         Lvl    AllPub
# 198          75       RM   Pave   NaN      Reg         Lvl    AllPub
# 199          20       RL   Pave   NaN      Reg         Lvl    AllPub
# 200          20       RM   Pave   NaN      Reg         Lvl    AllPub
# 201          20       RL   Pave   NaN      Reg         Lvl    AllPub
# 202          50       RL   Pave   NaN      Reg         Lvl    AllPub
# 203         120       RM   Pave   NaN      Reg         Lvl    AllPub
# 204          50       RM   Pave  Grvl      Reg         Lvl    AllPub
# 205          20       RL   Pave   NaN      Reg         Lvl    AllPub
# 206          20       RL   Pave   NaN      IR1         Lvl    AllPub
# 207          20       RL   Pave   NaN      IR1         Lvl    AllPub
# 208          60       RL   Pave   NaN      IR1         Low    AllPub
# 209          20       RL   Pave   NaN      Reg         Lvl    AllPub
# 210          30       RL   Pave   NaN      Reg         Lvl    AllPub
# 211          20       RL   Pave   NaN      Reg         Lvl    AllPub
# 212          60       FV   Pave   NaN      Reg         Lvl    AllPub
# 213          20       RL   Pave   NaN      IR2         Lvl    AllPub
# 214          60       RL   Pave   NaN      IR1         Lvl    AllPub
# 215          20       RL   Pave   NaN      IR1         Lvl    AllPub
# 216          20       RL   Pave   NaN      Reg         Lvl    AllPub
# 217          70       RM   Pave  Grvl      Reg         Lvl    AllPub
# 218          50       RL   Pave   NaN      IR1         Lvl    AllPub
# 219         120       RL   Pave   NaN      Reg         Lvl    AllPub
# 220          20       RL   Pave   NaN      IR1         Lvl    AllPub
# 221          60       RL   Pave   NaN      IR1         Lvl    AllPub
# 222          60       RL   Pave   NaN      Reg         Lvl    AllPub
# 223          20       RL   Pave   NaN      Reg         Lvl    AllPub
# 224          20       RL   Pave   NaN      Reg         Lvl    AllPub
# 225         160       RM   Pave   NaN      Reg         Lvl    AllPub
# 226          60       RL   Pave   NaN      IR1         Lvl    AllPub
# 227         160       RM   Pave   NaN      Reg         Lvl    AllPub
# 228          20       RL   Pave   NaN      Reg         Lvl    AllPub
# 229         120       RL   Pave   NaN      Reg         Lvl    AllPub
# 230          20       RL   Pave   NaN      Reg         Lvl    AllPub
# 231          60       RL   Pave   NaN      IR1         Lvl    AllPub
# 232         160       RM   Pave   NaN      Reg         Lvl    AllPub
# 233          20       RL   Pave   NaN      Reg         Lvl    AllPub
# 234          60       RL   Pave   NaN      Reg         Lvl    AllPub
# 235         160       RM   Pave   NaN      Reg         Lvl    AllPub
# 236          20       RL   Pave   NaN      Reg         Lvl    AllPub
# 237          60       RL   Pave   NaN      IR1         Lvl    AllPub
# 238          20       RL   Pave   NaN      Reg         Lvl    AllPub
# 239          50       RL   Pave   NaN      Reg         Lvl    AllPub
# 240          20       FV   Pave   NaN      Reg         Lvl    AllPub
# 241          30       RM   Pave   NaN      Reg         Lvl    AllPub
# 242          50       RM   Pave   NaN      Reg         Lvl    AllPub
# 243         160       RL   Pave   NaN      Reg         Lvl    AllPub
# 244          60       RL   Pave   NaN      IR1         Lvl    AllPub
# 245          20       RL   Pave   NaN      Reg         Lvl    AllPub
# 246         190       RM   Pave  Grvl      Reg         Lvl    AllPub
# 247          20       RL   Pave   NaN      Reg         Lvl    AllPub
# 248          60       RL   Pave   NaN      Reg         Lvl    AllPub
# 249          50       RL   Pave   NaN      IR2         Low    AllPub
# 250          30       RL   Pave   NaN      IR1         Lvl    AllPub
# 251         120       RM   Pave   NaN      IR1         HLS    AllPub
# 252          60       RL   Pave   NaN      IR1         Lvl    AllPub
# 253          80       RL   Pave   NaN      Reg         Lvl    AllPub
# 254          20       RL   Pave   NaN      Reg         Lvl    AllPub
# 255          60       RL   Pave   NaN      IR1         Lvl    AllPub
# 256          60       FV   Pave   NaN      IR1         Lvl    AllPub
# 257          20       RL   Pave   NaN      Reg         Lvl    AllPub
# 258          60       RL   Pave   NaN      Reg         Lvl    AllPub
# 259          20       RM   Pave   NaN      Reg         Lvl    AllPub
# 260          80       RL   Pave   NaN      Reg         Lvl    AllPub
# 261          60       RL   Pave   NaN      IR1         Lvl    AllPub
# 262          80       RL   Pave   NaN      IR1         Lvl    AllPub
# 263          50       RM   Pave   NaN      Reg         Lvl    AllPub
# 264          30       RM   Pave  Grvl      IR3         Bnk    AllPub
# 265          20       RL   Pave   NaN      IR1         Lvl    AllPub
# 266          60       RL   Pave   NaN      IR1         HLS    AllPub
# 267          75       RL   Pave   NaN      Reg         Bnk    AllPub
# 268          30       RM   Pave   NaN      Reg         Lvl    AllPub
# 269          20       RL   Pave   NaN      IR1         Lvl    AllPub
# 270          60       FV   Pave   NaN      Reg         Lvl    AllPub
# 271          20       RL   Pave   NaN      IR1         Low    AllPub
# 272          60       RL   Pave   NaN      IR1         Lvl    AllPub
# 273          20       RL   Pave   NaN      Reg         Lvl    AllPub
# 274          20       RL   Pave   NaN      Reg         Lvl    AllPub
# 275          50       RL   Pave   NaN      Reg         Lvl    AllPub
# 276          20       RL   Pave   NaN      IR1         Lvl    AllPub
# 277          20       RL   Pave   NaN      Reg         Lvl    AllPub
# 278          20       RL   Pave   NaN      Reg         Lvl    AllPub
# 279          60       RL   Pave   NaN      Reg         Lvl    AllPub
# 280          60       RL   Pave   NaN      Reg         Lvl    AllPub
# 281          20       FV   Pave  Pave      Reg         Lvl    AllPub
# 282         120       RL   Pave   NaN      Reg         Lvl    AllPub
# 283          20       RL   Pave   NaN      Reg         Lvl    AllPub
# 284         120       RL   Pave   NaN      Reg         Lvl    AllPub
# 285         160       FV   Pave  Pave      IR1         Lvl    AllPub
# 286          50       RL   Pave   NaN      IR1         Bnk    AllPub
# 287          20       RL   Pave   NaN      IR1         Lvl    AllPub
# 288          20       RL   Pave   NaN      IR1         Lvl    AllPub
# 289          70       RL   Pave   NaN      Reg         Lvl    AllPub
# 290          60       RL   Pave   NaN      Reg         Lvl    AllPub
# 291         190       RL   Pave  Grvl      Reg         Bnk    AllPub
# 292          50       RL   Pave   NaN      Reg         Lvl    AllPub
# 293          60       RL   Pave   NaN      IR1         Lvl    AllPub
# 294          20       RL   Pave   NaN      Reg         Lvl    AllPub
# 295          80       RL   Pave   NaN      IR1         Lvl    AllPub
# 296          50       RM   Pave   NaN      Reg         Lvl    AllPub
# 297          60       FV   Pave  Pave      IR1         Lvl    AllPub
# 298          60       RL   Pave   NaN      Reg         Lvl    AllPub
# 299          20       RL   Pave   NaN      Reg         Lvl    AllPub
# 300         190       RL   Pave   NaN      Reg         Lvl    AllPub
# 301          60       RL   Pave   NaN      IR3         Lvl    AllPub
# 302          20       RL   Pave   NaN      IR1         Lvl    AllPub
# 303          20       RL   Pave   NaN      Reg         Lvl    AllPub
# 304          75       RM   Pave   NaN      Reg         Lvl    AllPub
# 305          20       RL   Pave   NaN      Reg         Lvl    AllPub
# 306          60       RL   Pave   NaN      Reg         Lvl    AllPub
# 307          50       RM   Pave  Grvl      IR1         Lvl    AllPub
# 308          30       RL   Pave   NaN      IR1         Lvl    AllPub
# 309          20       RL   Pave   NaN      IR1         Lvl    AllPub
# 310          60       RL   Pave   NaN      IR1         Lvl    AllPub
# 311          20       RL   Pave   NaN      Reg         Lvl    AllPub
# 312         190       RM   Pave   NaN      Reg         Lvl    AllPub
# 313          20       RL   Pave   NaN      IR3         Low    AllPub
# 314          70       RM   Pave  Grvl      Reg         Lvl    AllPub
# 315          60       RL   Pave   NaN      IR1         Lvl    AllPub
# 316          60       RL   Pave   NaN      IR1         Lvl    AllPub
# 317          60       FV   Pave   NaN      Reg         Lvl    AllPub
# 318          60       RL   Pave   NaN      Reg         Low    AllPub
# 319          80       RL   Pave   NaN      Reg         Lvl    AllPub
# 320          60       RL   Pave   NaN      Reg         Lvl    AllPub
# 321          60       RL   Pave   NaN      IR1         Lvl    AllPub
# 322          60       RL   Pave   NaN      IR1         Lvl    AllPub
# 323          20       RM   Pave   NaN      Reg         Lvl    AllPub
# 324          80       RL   Pave   NaN      Reg         Lvl    AllPub
# 325          45       RM   Pave   NaN      Reg         Lvl    AllPub
# 326         120       RL   Pave   NaN      IR1         Lvl    AllPub
# 327          20       RL   Pave   NaN      Reg         Lvl    AllPub
# 328          75       RL   Pave  Pave      IR1         Bnk    AllPub
# 329          70       RM   Pave   NaN      Reg         Lvl    AllPub
# 330          90       RL   Pave   NaN      IR1         Lvl    AllPub
# 331          20       RL   Pave   NaN      Reg         Lvl    AllPub
# 332          20       RL   Pave   NaN      IR1         Lvl    AllPub
# 333         120       RM   Pave   NaN      Reg         Lvl    AllPub
# 334          60       RL   Pave   NaN      IR1         Lvl    AllPub
# 335         190       RL   Grvl   NaN      IR1         HLS    AllPub
# 336          20       RL   Pave   NaN      IR1         HLS    AllPub
# 337          20       RL   Pave   NaN      Reg         Lvl    AllPub
# 338          20       RL   Pave   NaN      Reg         Lvl    AllPub
# 339          20       RL   Pave   NaN      IR1         Lvl    AllPub
# 340          60       RL   Pave   NaN      Reg         Lvl    AllPub
# 341          20       RH   Pave   NaN      Reg         Lvl    AllPub
# 342          90       RL   Pave   NaN      Reg         Lvl    AllPub
# 343         120       RL   Pave   NaN      IR1         Lvl    AllPub
# 344         160       RM   Pave   NaN      Reg         Lvl    AllPub
# 345          50       RL   Pave   NaN      Reg         Lvl    AllPub
# 346          20       RL   Pave   NaN      IR1         Lvl    AllPub
# 347          20       RL   Pave   NaN      IR1         Lvl    AllPub
# 348         160       RL   Pave   NaN      Reg         Lvl    AllPub
# 349          60       RL   Pave   NaN      IR2         Lvl    AllPub
# 350         120       RL   Pave   NaN      IR1         Lvl    AllPub
# 351         120       RL   Pave   NaN      IR1         Low    AllPub
# 352          50       RL   Pave   NaN      Reg         Lvl    AllPub
# 353          30       RM   Pave   NaN      Reg         Lvl    AllPub
# 354          50       RL   Pave   NaN      Reg         Bnk    AllPub
# 355          20       RL   Pave   NaN      IR2         Lvl    AllPub
# 356          20       RL   Pave   NaN      IR1         Lvl    AllPub
# 357         120       RM   Pave   NaN      Reg         Lvl    AllPub
# 358          80       RL   Pave   NaN      IR1         Lvl    AllPub
# 359          60       RL   Pave   NaN      IR1         Lvl    AllPub
# 360          85       RL   Pave   NaN      IR1         Lvl    AllPub
# 361          50       RL   Pave  Pave      Reg         Lvl    AllPub
# 362          85       RL   Pave   NaN      Reg         Lvl    AllPub
# 363         160       RM   Pave   NaN      Reg         Lvl    AllPub
# 364          60       RL   Pave   NaN      IR1         Lvl    AllPub
# 365          70       RM   Pave   NaN      Reg         Lvl    AllPub
# 366          20       RL   Pave   NaN      IR1         Lvl    AllPub
# 367          80       RL   Pave   NaN      IR1         Lvl    AllPub
# 368          20       RL   Pave   NaN      Reg         Lvl    AllPub
# 369          20       RL   Pave   NaN      IR1         Lvl    AllPub
# 370          60       RL   Pave   NaN      IR1         Lvl    AllPub
# 371          50       RL   Pave   NaN      Reg         Lvl    AllPub
# 372         120       RL   Pave   NaN      Reg         Lvl    AllPub
# 373          20       RL   Pave   NaN      Reg         Lvl    AllPub
# 374          60       RL   Pave   NaN      Reg         Lvl    AllPub
# 375          30       RL   Pave   NaN      IR1         Low    AllPub
# 376          85       RL   Pave   NaN      IR1         Lvl    AllPub
# 377          60       FV   Pave   NaN      IR1         Lvl    AllPub
# 378          20       RL   Pave   NaN      Reg         Lvl    AllPub
# 379          60       RL   Pave   NaN      IR1         Lvl    AllPub
# 380          50       RL   Pave  Pave      Reg         Lvl    AllPub
# 381          20       FV   Pave  Pave      Reg         Lvl    AllPub
# 382          60       RL   Pave   NaN      IR1         Lvl    AllPub
# 383          45       RH   Pave   NaN      Reg         Lvl    AllPub
# 384          60       RL   Pave   NaN      IR2         Low    AllPub
# 385         120       RL   Pave   NaN      Reg         Lvl    AllPub
# 386          50       RL   Pave   NaN      Reg         Lvl    AllPub
# 387          80       RL   Pave   NaN      Reg         Lvl    AllPub
# 388          20       RL   Pave   NaN      IR1         Lvl    AllPub
# 389          60       RL   Pave   NaN      Reg         Lvl    AllPub
# 390          50       RL   Pave  Grvl      Reg         Lvl    AllPub
# 391          60       RL   Pave   NaN      IR1         Lvl    AllPub
# 392          20       RL   Pave   NaN      IR1         Lvl    AllPub
# 393          30       RL   Pave   NaN      Reg         Lvl    AllPub
# 394          50       RL   Pave   NaN      Reg         Lvl    AllPub
# 395          20       RL   Pave   NaN      Reg         Lvl    AllPub
# 396          20       RL   Pave   NaN      Reg         Low    AllPub
# 397          60       RL   Pave   NaN      Reg         Lvl    AllPub
# 398          30       RM   Pave   NaN      Reg         Lvl    AllPub
# 399          60       FV   Pave   NaN      Reg         Lvl    AllPub
# 400         120       RL   Pave   NaN      IR2         Lvl    AllPub
# 401          20       RL   Pave   NaN      IR1         Lvl    AllPub
# 402          30       RL   Pave   NaN      Reg         Lvl    AllPub
# 403          60       RL   Pave   NaN      Reg         Lvl    AllPub
# 404          60       RL   Pave   NaN      IR1         Lvl    AllPub
# 405          20       RL   Pave   NaN      IR1         Lvl    AllPub
# 406          50       RL   Pave   NaN      Reg         Lvl    AllPub
# 407          70       RL   Pave   NaN      Reg         Lvl    AllPub
# 408          60       RL   Pave   NaN      Reg         Lvl    AllPub
# 409          60       FV   Pave   NaN      Reg         Lvl    AllPub
# 410          20       RL   Pave   NaN      Reg         Lvl    AllPub
# 411         190       RL   Pave   NaN      Reg         Bnk    AllPub
# 412          20       FV   Pave   NaN      IR2         Lvl    AllPub
# 413          30       RM   Pave  Grvl      Reg         Lvl    AllPub
# 414          60       RL   Pave   NaN      IR2         Lvl    AllPub
# 415          20       RL   Pave   NaN      IR1         Lvl    AllPub
# 416          60       RL   Pave   NaN      Reg         Lvl    AllPub
# 417          70       RL   Pave   NaN      IR1         Lvl    AllPub
# 418          50       RL   Pave   NaN      Reg         Lvl    AllPub
# 419          20       RL   Pave   NaN      Reg         Lvl    AllPub
# 420          90       RM   Pave   NaN      Reg         Lvl    AllPub
# 421          20       RL   Pave   NaN      IR1         Lvl    AllPub
# 422          20       RL   Pave   NaN      Reg         HLS    AllPub
# 423          60       RL   Pave   NaN      Reg         Lvl    AllPub
# 424          20       RL   Pave   NaN      Reg         Lvl    AllPub
# 425          60       RM   Pave  Grvl      Reg         HLS    AllPub
# 426          80       RL   Pave   NaN      Reg         Low    AllPub
# 427          20       RL   Pave   NaN      IR1         Lvl    AllPub
# 428          20       RL   Pave   NaN      Reg         Lvl    AllPub
# 429          20       RL   Pave   NaN      IR1         Lvl    AllPub
# 430         160       RM   Pave   NaN      Reg         Lvl    AllPub
# 431          50       RM   Pave   NaN      IR1         Bnk    AllPub
# 432         160       RM   Pave   NaN      Reg         Lvl    AllPub
# 433          60       RL   Pave   NaN      IR1         Lvl    AllPub
# 434         180       RM   Pave   NaN      Reg         Lvl    AllPub
# 435          60       RL   Pave   NaN      IR2         Lvl    AllPub
# 436          50       RM   Pave   NaN      Reg         Lvl    AllPub
# 437          45       RM   Pave   NaN      Reg         Lvl    AllPub
# 438          30       RL   Pave   NaN      Reg         Lvl    AllPub
# 439          50       RL   Pave  Grvl      Reg         Lvl    AllPub
# 440          20       RL   Pave   NaN      Reg         Lvl    AllPub
# 441          90       RL   Pave   NaN      Reg         Lvl    AllPub
# 442          50       RM   Pave   NaN      Reg         Lvl    AllPub
# 443         120       RL   Pave   NaN      Reg         Lvl    AllPub
# 444          60       RL   Pave   NaN      Reg         Lvl    AllPub
# 445          20       RL   Pave   NaN      Reg         Lvl    AllPub
# 446          20       RL   Pave   NaN      IR1         Lvl    AllPub
# 447          60       RL   Pave   NaN      IR1         Lvl    AllPub
# 448          50       RM   Pave   NaN      Reg         Bnk    AllPub
# 449          50       RM   Pave   NaN      Reg         Lvl    AllPub
# 450          30       RM   Pave   NaN      Reg         Lvl    AllPub
# 451          20       RL   Pave   NaN      IR1         Low    AllPub
# 452          60       RL   Pave   NaN      IR1         Lvl    AllPub
# 453          60       FV   Pave   NaN      Reg         Lvl    AllPub
# 454          90       RL   Pave   NaN      Reg         Lvl    AllPub
# 455          20       RL   Pave   NaN      Reg         Lvl    AllPub
# 456          70       RM   Pave  Grvl      Reg         Lvl    AllPub
# 457          20       RL   Pave   NaN      IR1         Low    AllPub
# 458          70       RM   Pave  Grvl      Reg         Lvl    AllPub
# 459          50       RL   Pave   NaN      IR1         Bnk    AllPub
# 460          60       FV   Pave   NaN      IR1         Lvl    AllPub
# 461          70       RL   Pave   NaN      Reg         Lvl    AllPub
# 462          20       RL   Pave   NaN      IR1         Lvl    AllPub
# 463          70       RL   Pave   NaN      IR1         HLS    AllPub
# 464          20       RL   Pave   NaN      Reg         HLS    AllPub
# 465         120       RM   Pave   NaN      Reg         Lvl    AllPub
# 466          20       RL   Pave   NaN      Reg         Lvl    AllPub
# 467          70       RL   Pave   NaN      Reg         Lvl    AllPub
# 468          20       RL   Pave   NaN      IR1         Lvl    AllPub
# 469          60       RL   Pave   NaN      IR1         Lvl    AllPub
# 470         120       RL   Pave   NaN      IR1         Lvl    AllPub
# 471          60       RL   Pave   NaN      Reg         Lvl    AllPub
# 472         180       RM   Pave   NaN      Reg         Lvl    AllPub
# 473          20       RL   Pave   NaN      IR1         Lvl    AllPub
# 474         120       RL   Pave   NaN      Reg         Lvl    AllPub
# 475          20       RL   Pave   NaN      Reg         Lvl    AllPub
# 476          20       RL   Pave   NaN      Reg         Lvl    AllPub
# 477          60       RL   Pave   NaN      Reg         Lvl    AllPub
# 478          20       RL   Pave   NaN      Reg         Lvl    AllPub
# 479          30       RM   Pave   NaN      Reg         Bnk    AllPub
# 480          20       RL   Pave   NaN      IR1         Lvl    AllPub
# 481          20       RL   Pave   NaN      IR1         HLS    AllPub
# 482          70       RM   Pave  Pave      Reg         Lvl    AllPub
# 483         120       RM   Pave   NaN      Reg         Lvl    AllPub
# 484          20       RL   Pave   NaN      IR1         Lvl    AllPub
# 485          20       RL   Pave   NaN      Reg         Lvl    AllPub
# 486          20       RL   Pave   NaN      Reg         Lvl    AllPub
# 487          20       RL   Pave   NaN      IR1         Lvl    AllPub
# 488         190       RL   Pave   NaN      Reg         Lvl    AllPub
# 489         180       RM   Pave   NaN      Reg         Lvl    AllPub
# 490         160       RM   Pave   NaN      Reg         Lvl    AllPub
# 491          50       RL   Pave   NaN      Reg         Lvl    AllPub
# 492          60       RL   Pave   NaN      IR1         Lvl    AllPub
# 493          20       RL   Pave   NaN      Reg         Lvl    AllPub
# 494          30       RM   Pave   NaN      Reg         Lvl    AllPub
# 495          30  C (all)   Pave   NaN      Reg         Lvl    AllPub
# 496          20       RL   Pave   NaN      IR1         Lvl    AllPub
# 497          50       RL   Pave  Pave      Reg         Lvl    AllPub
# 498          20       RL   Pave   NaN      Reg         Lvl    AllPub
# 499          20       RL   Pave   NaN      IR1         Lvl    AllPub
# 500         160       RM   Pave   NaN      Reg         Lvl    AllPub
# 501          60       FV   Pave   NaN      Reg         Lvl    AllPub
# 502          20       RL   Pave   NaN      Reg         Lvl    AllPub
# 503          20       RL   Pave   NaN      IR1         Lvl    AllPub
# 504         160       RL   Pave   NaN      Reg         Lvl    AllPub
# 505          90       RM   Pave  Grvl      Reg         Lvl    AllPub
# 506          60       RL   Pave   NaN      IR1         Lvl    AllPub
# 507          20       FV   Pave   NaN      IR1         Lvl    AllPub
# 508          70       RM   Pave   NaN      Reg         Lvl    AllPub
# 509          20       RL   Pave   NaN      Reg         Lvl    AllPub
# 510          20       RL   Pave   NaN      Reg         Lvl    AllPub
# 511         120       RL   Pave   NaN      IR1         Lvl    AllPub
# 512          20       RL   Pave   NaN      Reg         Lvl    AllPub
# 513          20       RL   Pave   NaN      Reg         Bnk    AllPub
# 514          45       RL   Pave   NaN      Reg         Lvl    AllPub
# 515          20       RL   Pave   NaN      Reg         Lvl    AllPub
# 516          80       RL   Pave   NaN      IR1         Lvl    AllPub
# 517          60       RL   Pave   NaN      IR1         Lvl    AllPub
# 518          60       RL   Pave   NaN      IR1         Lvl    AllPub
# 519          70       RL   Pave   NaN      Reg         Lvl    AllPub
# 520         190       RL   Pave  Grvl      Reg         Lvl    AllPub
# 521          20       RL   Pave   NaN      IR1         Lvl    AllPub
# 522          50       RM   Pave   NaN      Reg         Lvl    AllPub
# 523          60       RL   Pave   NaN      IR1         Bnk    AllPub
# 524          60       RL   Pave   NaN      IR1         Lvl    AllPub
# 525          20       FV   Pave  Pave      Reg         Lvl    AllPub
# 526          20       RL   Pave   NaN      Reg         Lvl    AllPub
# 527          60       RL   Pave   NaN      IR1         Lvl    AllPub
# 528          30       RL   Pave   NaN      IR1         Lvl    AllPub
# 529          20       RL   Pave   NaN      IR1         Lvl    AllPub
# 530          80       RL   Pave   NaN      Reg         Lvl    AllPub
# 531          70       RM   Pave   NaN      IR1         Lvl    AllPub
# 532          20       RL   Pave   NaN      Reg         Lvl    AllPub
# 533          20       RL   Pave   NaN      Reg         Low    AllPub
# 534          60       RL   Pave   NaN      IR1         Lvl    AllPub
# 535         190       RL   Pave   NaN      Reg         Lvl    AllPub
# 536          60       RL   Pave   NaN      IR1         Lvl    AllPub
# 537          20       RL   Pave   NaN      IR1         Lvl    AllPub
# 538          20       RL   Pave   NaN      IR1         Lvl    AllPub
# 539          20       RL   Pave   NaN      Reg         Lvl    AllPub
# 540          20       RL   Pave   NaN      Reg         Lvl    AllPub
# 541          60       RL   Pave   NaN      Reg         Lvl    AllPub
# 542          20       RL   Pave   NaN      Reg         Lvl    AllPub
# 543         120       RH   Pave   NaN      Reg         Lvl    AllPub
# 544          60       RL   Pave   NaN      IR1         Lvl    AllPub
# 545          50       RL   Pave   NaN      IR1         Lvl    AllPub
# 546          50       RL   Pave   NaN      IR1         Bnk    AllPub
# 547          85       RL   Pave   NaN      Reg         Lvl    AllPub
# 548          20       RM   Pave   NaN      IR1         HLS    AllPub
# 549          60       FV   Pave   NaN      Reg         Lvl    AllPub
# 550         120       RL   Pave   NaN      Reg         Lvl    AllPub
# 551          20       RM   Pave   NaN      Reg         Lvl    AllPub
# 552          20       RL   Pave   NaN      IR1         Lvl    AllPub
# 553          20       RL   Pave   NaN      Reg         Lvl    AllPub
# 554          60       RL   Pave   NaN      Reg         Lvl    AllPub
# 555          45       RM   Pave   NaN      Reg         Lvl    AllPub
# 556          20       RL   Pave   NaN      IR1         Lvl    AllPub
# 557          50  C (all)   Pave   NaN      Reg         Low    AllPub
# 558          60       RL   Pave   NaN      IR2         HLS    AllPub
# 559         120       RL   Pave   NaN      Reg         Lvl    AllPub
# 560          20       RL   Pave   NaN      IR1         Lvl    AllPub
# 561          20       RL   Pave   NaN      Reg         Lvl    AllPub
# 562          30       RL   Pave   NaN      Reg         Lvl    AllPub
# 563          50       RL   Pave   NaN      Reg         Lvl    AllPub
# 564          60       RL   Pave   NaN      IR1         Lvl    AllPub
# 565          70       RL   Pave   NaN      Reg         Bnk    AllPub
# 566          60       RL   Pave   NaN      IR1         Lvl    AllPub
# 567          20       RL   Pave   NaN      IR1         Lvl    AllPub
# 568          50       RL   Pave   NaN      IR1         Low    AllPub
# 569          90       RL   Pave   NaN      IR1         Lvl    AllPub
# 570          90       RL   Pave   NaN      IR1         Lvl    AllPub
# 571          20       RL   Pave   NaN      Reg         Lvl    AllPub
# 572          60       RL   Pave   NaN      IR1         HLS    AllPub
# 573          80       RL   Pave   NaN      IR1         Lvl    AllPub
# 574          80       RL   Pave   NaN      Reg         Lvl    AllPub
# 575          50       RL   Pave   NaN      Reg         Lvl    AllPub
# 576          50       RL   Pave   NaN      Reg         Lvl    AllPub
# 577          80       RL   Pave   NaN      IR1         Lvl    AllPub
# 578         160       FV   Pave  Pave      Reg         Lvl    AllPub
# 579          50       RM   Pave  Grvl      Reg         Lvl    AllPub
# 580          20       RL   Pave   NaN      IR1         Lvl    AllPub
# 581          20       RL   Pave   NaN      Reg         Lvl    AllPub
# 582          90       RL   Grvl   NaN      Reg         Lvl    AllPub
# 583          75       RM   Pave   NaN      Reg         Lvl    AllPub
# 584          50       RM   Pave   NaN      Reg         Lvl    AllPub
# 585          20       RL   Pave   NaN      Reg         Lvl    AllPub
# 586          30       RL   Pave   NaN      Reg         Lvl    AllPub
# 587          85       RL   Pave   NaN      IR1         Lvl    AllPub
# 588          20       RL   Pave   NaN      IR1         Low    AllPub
# 589          40       RM   Pave   NaN      Reg         Lvl    AllPub
# 590          60       RL   Pave   NaN      Reg         Lvl    AllPub
# 591          60       RL   Pave   NaN      IR1         Lvl    AllPub
# 592          20       RL   Pave   NaN      Reg         Lvl    AllPub
# 593         120       RM   Pave   NaN      Reg         Lvl    AllPub
# 594          20       RL   Pave   NaN      IR1         Lvl    AllPub
# 595          20       RL   Pave   NaN      IR1         Lvl    AllPub
# 596          70       RM   Pave  Grvl      Reg         Lvl    AllPub
# 597         120       RL   Pave   NaN      Reg         Lvl    AllPub
# 598          20       RL   Pave   NaN      Reg         Bnk    AllPub
# 599         160       RM   Pave   NaN      Reg         Lvl    AllPub
# 600          60       RL   Pave   NaN      Reg         Lvl    AllPub
# 601          50       RM   Pave   NaN      Reg         Bnk    AllPub
# 602          60       RL   Pave   NaN      IR1         Lvl    AllPub
# 603         160       FV   Pave  Pave      Reg         Lvl    AllPub
# 604          20       RL   Pave   NaN      IR1         Lvl    AllPub
# 605          60       RL   Pave   NaN      Reg         Lvl    AllPub
# 606          20       RL   Pave   NaN      IR2         Low    AllPub
# 607          20       RL   Pave   NaN      Reg         Bnk    AllPub
# 608          70       RL   Pave   NaN      Reg         HLS    AllPub
# 609          20       RL   Pave   NaN      Reg         Lvl    AllPub
# 610          60       RL   Pave   NaN      Reg         Lvl    AllPub
# 611          80       RL   Pave   NaN      IR1         Lvl    AllPub
# 612          60       RL   Pave   NaN      Reg         Lvl    AllPub
# 613          20       RL   Pave   NaN      Reg         Lvl    AllPub
# 614         180       RM   Pave   NaN      Reg         Lvl    AllPub
# 615          85       RL   Pave   NaN      Reg         Lvl    AllPub
# 616          60       RL   Pave   NaN      IR1         Lvl    AllPub
# 617          45       RL   Pave   NaN      Reg         HLS    AllPub
# 618          20       RL   Pave   NaN      Reg         Lvl    AllPub
# 619          60       RL   Pave   NaN      Reg         Lvl    AllPub
# 620          30       RL   Pave  Grvl      Reg         Lvl    AllPub
# 621          60       RL   Pave   NaN      Reg         Lvl    AllPub
# 622          20       RL   Pave   NaN      Reg         Lvl    AllPub
# 623         160       FV   Pave   NaN      Reg         Lvl    AllPub
# 624          60       RL   Pave   NaN      Reg         Lvl    AllPub
# 625          20       RL   Pave   NaN      IR1         Lvl    AllPub
# 626          20       RL   Pave   NaN      IR1         Lvl    AllPub
# 627          80       RL   Pave   NaN      Reg         Lvl    AllPub
# 628          60       RL   Pave   NaN      IR1         HLS    AllPub
# 629          80       RL   Pave   NaN      Reg         Lvl    AllPub
# 630          70       RM   Pave  Grvl      Reg         Lvl    AllPub
# 631         120       RL   Pave   NaN      Reg         Lvl    AllPub
# 632          20       RL   Pave   NaN      Reg         Lvl    AllPub
# 633          20       RL   Pave   NaN      Reg         Lvl    AllPub
# 634          90       RL   Pave   NaN      Reg         Lvl    AllPub
# 635         190       RH   Pave  Pave      Reg         Bnk    AllPub
# 636          30       RM   Pave   NaN      Reg         Lvl    AllPub
# 637         190       RM   Pave   NaN      Reg         Lvl    AllPub
# 638          30       RL   Pave   NaN      Reg         Lvl    AllPub
# 639         120       RL   Pave   NaN      Reg         Lvl    AllPub
# 640         120       RL   Pave   NaN      IR1         Lvl    AllPub
# 641          60       FV   Pave   NaN      Reg         Lvl    AllPub
# 642          80       RL   Pave   NaN      Reg         Lvl    AllPub
# 643          60       RL   Pave   NaN      Reg         Lvl    AllPub
# 644          20       FV   Pave   NaN      Reg         Lvl    AllPub
# 645          20       RL   Pave   NaN      IR1         Lvl    AllPub
# 646          20       RL   Pave   NaN      Reg         Lvl    AllPub
# 647          20       RL   Pave   NaN      IR1         Lvl    AllPub
# 648          60       RL   Pave   NaN      Reg         Lvl    AllPub
# 649         180       RM   Pave   NaN      Reg         Lvl    AllPub
# 650          60       FV   Pave   NaN      Reg         Lvl    AllPub
# 651          70       RL   Pave   NaN      Reg         Lvl    AllPub
# 652          60       RL   Pave   NaN      Reg         Lvl    AllPub
# 653          50       RM   Pave  Grvl      Reg         Lvl    AllPub
# 654          20       RL   Pave   NaN      IR1         Lvl    AllPub
# 655         160       RM   Pave   NaN      Reg         Lvl    AllPub
# 656          20       RL   Pave   NaN      IR1         Lvl    AllPub
# 657          70       RL   Pave   NaN      Reg         HLS    AllPub
# 658          50       RL   Pave   NaN      Reg         Lvl    AllPub
# 659          20       RL   Pave   NaN      Reg         Lvl    AllPub
# 660          60       RL   Pave   NaN      Reg         Lvl    AllPub
# 661          60       RL   Pave   NaN      IR2         Lvl    AllPub
# 662          20       RL   Pave   NaN      Reg         Lvl    AllPub
# 663          85       RL   Pave   NaN      Reg         Lvl    AllPub
# 664          20       RL   Pave   NaN      IR2         Lvl    AllPub
# ...
# 1276         TA          Y    NaN    NaN         NaN       WD        Normal
# 1277         TA          Y    NaN    NaN         NaN       WD        Normal
# 1278         TA          Y    NaN    NaN         NaN       WD        Normal
# 1279         TA          Y    NaN    NaN         NaN      COD       Abnorml
# 1280         TA          Y    NaN    NaN         NaN       WD        Normal
# 1281         Gd          Y    NaN    NaN         NaN       WD        Normal
# 1282         TA          Y    NaN    NaN         NaN       WD        Normal
# 1283        NaN          Y    NaN    NaN         NaN       WD        Normal
# 1284         TA          Y    NaN    NaN         NaN       WD        Normal
# 1285         TA          Y    NaN    NaN         NaN       WD        Normal
# 1286         TA          Y    NaN    NaN         NaN       WD        Normal
# 1287         TA          N    NaN    NaN         NaN       WD        Normal
# 1288         TA          Y    NaN    NaN         NaN       WD        Normal
# 1289         TA          Y    NaN    NaN         NaN      New       Partial
# 1290         TA          Y    NaN    NaN         NaN       WD        Normal
# 1291         TA          Y    NaN    NaN         NaN       WD        Normal
# 1292         TA          Y    NaN    NaN         NaN       WD        Normal
# 1293         TA          Y    NaN   GdWo         NaN       WD        Normal
# 1294         TA          N    NaN    NaN         NaN       WD        Normal
# 1295         TA          Y    NaN   GdWo         NaN       WD        Normal
# 1296         TA          Y    NaN  MnPrv         NaN       WD        Normal
# 1297         TA          Y    NaN    NaN         NaN      New       Partial
# 1298         TA          Y     Gd    NaN         NaN      New       Partial
# 1299         TA          Y    NaN  GdPrv         NaN       WD        Normal
# 1300         TA          Y    NaN    NaN         NaN       WD        Normal
# 1301         TA          P    NaN    NaN         NaN       WD        Normal
# 1302         TA          Y    NaN    NaN         NaN       WD        Normal
# 1303         TA          Y    NaN    NaN         NaN       WD        Normal
# 1304         TA          Y    NaN    NaN         NaN       WD        Normal
# 1305         TA          Y    NaN    NaN         NaN       WD        Normal
# 1306         TA          Y    NaN    NaN         NaN      New       Partial
# 1307         TA          Y    NaN    NaN         NaN       WD        Normal
# 1308         TA          Y    NaN   GdWo         NaN       WD        Normal
# 1309         TA          Y    NaN   GdWo         NaN       WD        Normal
# 1310         TA          Y    NaN    NaN         NaN       WD        Normal
# 1311         TA          Y    NaN    NaN         NaN      New       Partial
# 1312         Gd          Y    NaN    NaN         NaN       WD        Normal
# 1313         TA          Y    NaN    NaN         NaN       WD        Normal
# 1314         TA          Y    NaN    NaN         NaN       WD        Normal
# 1315         TA          Y    NaN    NaN         NaN       WD        Normal
# 1316         TA          Y    NaN    NaN         NaN       WD        Normal
# 1317         TA          Y    NaN    NaN         NaN      New       Partial
# 1318         TA          Y    NaN    NaN         NaN       WD        Normal
# 1319         TA          Y    NaN    NaN         NaN       WD        Normal
# 1320         TA          Y    NaN    NaN         NaN       WD        Normal
# 1321         Fa          Y    NaN    NaN         NaN       WD        Normal
# 1322         TA          Y    NaN    NaN         NaN       WD        Normal
# 1323        NaN          Y    NaN    NaN         NaN       WD        Normal
# 1324         TA          Y    NaN    NaN         NaN      New       Partial
# 1325        NaN          N    NaN  MnPrv         NaN       WD        Normal
# 1326        NaN          Y    NaN    NaN         NaN       WD        Normal
# 1327         TA          Y    NaN  MnPrv         NaN       WD        Normal
# 1328         TA          Y    NaN  MnPrv        Shed       WD        Normal
# 1329         TA          Y    NaN    NaN         NaN       WD        Normal
# 1330         TA          Y    NaN    NaN         NaN       WD        Normal
# 1331         TA          Y    NaN    NaN         NaN       WD        Normal
# 1332         Fa          Y    NaN    NaN         NaN       WD        Normal
# 1333         TA          Y    NaN  MnPrv         NaN       WD        Normal
# 1334         TA          Y    NaN    NaN         NaN       WD        Normal
# 1335         TA          Y    NaN    NaN         NaN       WD        Normal
# 1336         TA          Y    NaN    NaN         NaN       WD        Normal
# 1337        NaN          N    NaN    NaN         NaN       WD        Normal
# 1338         TA          Y    NaN    NaN         NaN       WD        Normal
# 1339         TA          Y    NaN    NaN         NaN       WD        Normal
# 1340         TA          Y    NaN   GdWo         NaN       WD        Normal
# 1341         TA          Y    NaN    NaN         NaN       WD        Normal
# 1342         TA          Y    NaN    NaN         NaN       WD        Normal
# 1343         Fa          Y    NaN    NaN         NaN       WD        Normal
# 1344         TA          Y    NaN    NaN         NaN      New       Partial
# 1345         TA          Y    NaN    NaN         NaN       WD        Normal
# 1346         TA          Y    NaN    NaN         NaN       WD        Normal
# 1347         TA          Y    NaN    NaN         NaN      New       Partial
# 1348         TA          Y    NaN    NaN         NaN       WD        Normal
# 1349        NaN          Y    NaN    NaN         NaN       WD        Normal
# 1350         TA          Y    NaN    NaN         NaN       WD        Normal
# 1351         TA          Y    NaN    NaN         NaN       WD        Normal
# 1352         TA          N    NaN    NaN         NaN       WD        Normal
# 1353         TA          Y    NaN    NaN         NaN       WD        Normal
# 1354         TA          Y    NaN    NaN         NaN       WD        Normal
# 1355         TA          Y    NaN  GdPrv         NaN       WD        Normal
# 1356         TA          Y    NaN   GdWo         NaN       WD        Normal
# 1357         TA          Y    NaN    NaN         NaN       WD        Normal
# 1358         TA          Y    NaN    NaN         NaN       WD        Normal
# 1359         TA          Y    NaN    NaN         NaN       WD        Normal
# 1360         TA          Y    NaN    NaN         NaN       WD        Normal
# 1361         TA          Y    NaN    NaN         NaN       WD        Normal
# 1362         TA          Y    NaN    NaN         NaN       WD        Normal
# 1363         TA          Y    NaN    NaN         NaN      New       Partial
# 1364         TA          Y    NaN    NaN         NaN       WD       Abnorml
# 1365         TA          Y    NaN    NaN         NaN       WD        Normal
# 1366         TA          Y    NaN    NaN         NaN       WD       Abnorml
# 1367         TA          Y    NaN    NaN         NaN       WD        Normal
# 1368         TA          Y    NaN    NaN         NaN       WD        Normal
# 1369         TA          Y    NaN    NaN         NaN       WD        Normal
# 1370         TA          Y    NaN    NaN         NaN       WD        Normal
# 1371         TA          Y    NaN  MnPrv         NaN       WD        Normal
# 1372         TA          Y    NaN    NaN         NaN       WD        Normal
# 1373         TA          Y    NaN    NaN         NaN       WD        Normal
# 1374         TA          Y    NaN    NaN         NaN       WD        Normal
# 1375         TA          Y    NaN    NaN         NaN      New       Partial
# 1376         TA          Y    NaN    NaN         NaN       WD        Normal
# 1377         TA          Y    NaN    NaN         NaN       WD        Normal
# 1378         TA          Y    NaN    NaN         NaN       WD        Normal
# 1379         TA          Y    NaN    NaN         NaN       WD        Normal
# 1380         Fa          Y    NaN    NaN         NaN       WD        Normal
# 1381         TA          Y    NaN    NaN         NaN       WD        Normal
# 1382         TA          N    NaN    NaN         NaN       WD        Normal
# 1383         TA          N    NaN    NaN         NaN       WD        Normal
# 1384         TA          P    NaN  MnPrv         NaN       WD        Normal
# 1385         TA          N    NaN  MnPrv         NaN       WD        Normal
# 1386         TA          Y     Fa  MnPrv        TenC       WD        Normal
# 1387         TA          Y    NaN   GdWo         NaN      CWD        Family
# 1388         TA          Y    NaN    NaN         NaN       WD        Normal
# 1389         TA          Y    NaN    NaN         NaN       WD        Normal
# 1390         TA          Y    NaN    NaN         NaN       WD        Normal
# 1391         TA          Y    NaN    NaN         NaN       WD        Normal
# 1392         TA          Y    NaN   MnWw         NaN       WD        Normal
# 1393         TA          Y    NaN    NaN         NaN       WD        Normal
# 1394         TA          Y    NaN    NaN         NaN      New       Partial
# 1395         TA          Y    NaN    NaN         NaN       WD        Normal
# 1396         TA          N    NaN    NaN         NaN       WD        Normal
# 1397         Fa          N    NaN    NaN         NaN       WD        Normal
# 1398         TA          Y    NaN  GdPrv         NaN       WD        Normal
# 1399         TA          Y    NaN  MnPrv         NaN       WD        Normal
# 1400         TA          Y    NaN    NaN         NaN       WD        Normal
# 1401         TA          Y    NaN    NaN         NaN       WD        Normal
# 1402         TA          Y    NaN    NaN         NaN      New       Partial
# 1403         TA          Y    NaN    NaN         NaN       WD        Normal
# 1404         TA          Y    NaN  MnPrv         NaN       WD        Family
# 1405         TA          Y    NaN    NaN         NaN       WD        Normal
# 1406         TA          Y    NaN  MnPrv         NaN       WD        Normal
# 1407        NaN          Y    NaN  MnPrv         NaN       WD        Normal
# 1408         TA          Y    NaN    NaN         NaN       WD        Normal
# 1409         TA          Y    NaN  MnPrv         NaN       WD        Normal
# 1410         TA          Y    NaN    NaN         NaN       WD        Normal
# 1411         TA          Y    NaN  MnPrv         NaN       WD        Normal
# 1412         TA          Y    NaN    NaN         NaN       WD        Normal
# 1413         TA          Y    NaN    NaN         NaN      COD       Abnorml
# 1414         TA          N    NaN    NaN         NaN       WD        Normal
# 1415         TA          Y    NaN    NaN         NaN       WD        Normal
# 1416         TA          N    NaN    NaN         NaN       WD        Normal
# 1417         TA          Y    NaN    NaN         NaN       WD        Normal
# 1418         TA          Y    NaN    NaN         NaN      COD        Normal
# 1419         TA          Y    NaN    NaN         NaN       WD        Normal
# 1420         TA          Y    NaN    NaN         NaN       WD        Normal
# 1421         TA          Y    NaN    NaN         NaN       WD        Normal
# 1422         TA          Y    NaN    NaN         NaN       WD        Normal
# 1423         Gd          Y     Gd  GdPrv         NaN       WD        Alloca
# 1424         TA          Y    NaN   GdWo         NaN       WD        Normal
# 1425         TA          Y    NaN    NaN         NaN       WD        Normal
# 1426         TA          Y    NaN    NaN         NaN       WD        Normal
# 1427         TA          Y    NaN    NaN         NaN       WD        Normal
# 1428         TA          Y    NaN  MnPrv         NaN       WD       Abnorml
# 1429         TA          Y    NaN    NaN         NaN       WD        Normal
# 1430         TA          Y    NaN    NaN         NaN       WD        Normal
# 1431         TA          Y    NaN    NaN         NaN       WD        Normal
# 1432         Fa          Y    NaN    NaN         NaN       WD        Normal
# 1433         TA          Y    NaN    NaN         NaN       WD        Normal
# 1434         TA          P    NaN    NaN         NaN       WD        Normal
# 1435         TA          Y    NaN  GdPrv         NaN      COD       Abnorml
# 1436         TA          Y    NaN   GdWo         NaN       WD        Normal
# 1437         TA          Y    NaN    NaN         NaN      New       Partial
# 1438         TA          Y    NaN  MnPrv         NaN       WD        Normal
# 1439         TA          Y    NaN    NaN         NaN       WD        Normal
# 1440         TA          Y    NaN    NaN         NaN       WD        Normal
# 1441         TA          Y    NaN    NaN         NaN       WD        Normal
# 1442         TA          Y    NaN    NaN         NaN       WD        Normal
# 1443         Po          P    NaN    NaN         NaN       WD        Normal
# 1444         TA          Y    NaN    NaN         NaN       WD        Normal
# 1445         TA          Y    NaN    NaN         NaN       WD        Normal
# 1446         TA          P    NaN    NaN         NaN       WD        Normal
# 1447         TA          Y    NaN    NaN         NaN       WD        Normal
# 1448         TA          Y    NaN   GdWo         NaN       WD        Normal
# 1449        NaN          Y    NaN    NaN         NaN       WD       Abnorml
# 1450        NaN          Y    NaN    NaN         NaN       WD        Normal
# 1451         TA          Y    NaN    NaN         NaN      New       Partial
# 1452         TA          Y    NaN    NaN         NaN       WD        Normal
# 1453        NaN          Y    NaN    NaN         NaN       WD       Abnorml
# 1454         TA          Y    NaN    NaN         NaN       WD        Normal
# 1455         TA          Y    NaN    NaN         NaN       WD        Normal
# 1456         TA          Y    NaN  MnPrv         NaN       WD        Normal
# 1457         TA          Y    NaN  GdPrv        Shed       WD        Normal
# 1458         TA          Y    NaN    NaN         NaN       WD        Normal
# 1459         TA          Y    NaN    NaN         NaN       WD        Normal
# (1460, 135)
# Id
# MSSubClass
# MSZoning
# LotFrontage
# LotArea
# Street
# Alley
# LotShape
# LandContour
# Utilities
# LotConfig
# LandSlope
# Neighborhood
# Condition1
# Condition2
# BldgType
# HouseStyle
# OverallQual
# OverallCond
# YearBuilt
# YearRemodAdd
# RoofStyle
# RoofMatl
# Exterior1st
# Exterior2nd
# MasVnrType
# MasVnrArea
# ExterQual
# ExterCond
# Foundation
# BsmtQual
# BsmtCond
# BsmtExposure
# BsmtFinType1
# BsmtFinSF1
# BsmtFinType2
# BsmtFinSF2
# BsmtUnfSF
# Heating
# HeatingQC
# CentralAir
# Electrical
# 1stFlrSF
# 2ndFlrSF
# LowQualFinSF
# BsmtFullBath
# BsmtHalfBath
# FullBath
# HalfBath
# BedroomAbvGr
# KitchenAbvGr
# KitchenQual
# Functional
# Fireplaces
# FireplaceQu
# GarageType
# GarageYrBlt
# GarageFinish
# GarageCars
# GarageQual
# GarageCond
# PavedDrive
# WoodDeckSF
# OpenPorchSF
# EnclosedPorch
# 3SsnPorch
# ScreenPorch
# PoolQC
# Fence
# MiscFeature
# MiscVal
# MoSold
# YrSold
# SaleType
# SaleCondition
# SalePrice
# MasVnrArea2
# MasVnrArea2_0
# MasVnrArea2_50
# MasVnrArea2_100
# MasVnrArea2_150
# MasVnrArea2_200
# MasVnrArea2_250
# MasVnrArea2_300
# MasVnrArea2_350
# MasVnrArea2_400
# MasVnrArea2_other
# MSSubClass_60
# MSSubClass_50
# MSSubClass_120
# MSSubClass_80
# MSSubClass_160
# MSSubClass_90
# MSSubClass_30
# MSSubClass_70
# MSSubClass_other
# LotFrontage_none
# LotFrontage_50
# LotFrontage_60
# LotFrontage_70
# LotFrontage_80
# LotFrontage_90
# LotFrontage_other
# LotArea_5
# LotArea_6
# LotArea_7
# LotArea_8
# LotArea_9
# LotArea_10
# LotArea_11
# LotArea_12
# LotArea_13
# LotArea_14
# LotArea_other
# YearBuilt_30
# YearBuilt_40
# YearBuilt_50
# YearBuilt_60
# YearBuilt_70
# YearBuilt_80
# YearBuilt_90
# YearBuilt_00
# YearRemodAdd_50
# YearRemodAdd_60
# YearRemodAdd_70
# YearRemodAdd_80
# YearRemodAdd_90
# YearRemodAdd_00
# OtherRmsAbvGr
# HasBsmt
# Has2ndFlr
# TotalPorchSqFt
# HasPool
# HasManyFireplaces
# HasLargeGarage

# %%
train.to_csv('data/train_fe.csv',index=False)
test.to_csv('data/test_fe.csv',index=False)
with open('data/features_fe.txt', "w") as feature_file:
    feature_file.write(np.array2string(train.columns, separator=","))

# %%
##
## convert categoricals to integers
##
after_train = train.copy()

#after_dev = after_train[~mask].copy()
#after_train = after_train[mask].copy()

train_labels = after_train["SalePrice"].copy()
after_train = after_train.drop( ["SalePrice"], axis=1 )
after_train = after_train.drop( ["Id"], axis=1 )

#dev_labels = after_dev["SalePrice"].copy()
#after_dev = after_dev.drop( ["SalePrice"], axis=1 ) 
#after_dev = after_dev.drop( ["Id"], axis=1 ) 

#print after_train.dtypes
#print after_train.select_dtypes(include=['category']).columns
#print after_train.shape
test = pd.get_dummies(after_train, columns = after_train.select_dtypes(include=['category']).columns)
test = test.drop( ["LotFrontage", "GarageYrBlt"], axis=1 )
total = test.isnull().sum().sort_values(ascending=False)
print total.head(10)

reg = LinearRegression()
reg.fit(test, train_labels)
#print("R^2 value: " + str(reg.score(after_dev, dev_labels)))
# Out:
# SaleCondition_Partial    0
# MSSubClass_160           0
# LotShape_IR2             0
# LotShape_IR3             0
# LotShape_Reg             0
# LandContour_Bnk          0
# LandContour_HLS          0
# LandContour_Low          0
# LandContour_Lvl          0
# Utilities_AllPub         0
# dtype: int64
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
